# %%
''' This notebook contains the following:
    M1 - GPT 3.5
    M2 - GPT 4
    Both the models are unfinetuned
'''
# !pip install openai==0.28
# !nvidia-smi
# !pip install pandas
# !CT_CUBLAS=1 pip install ctransformers --no-binary ctransformers
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Mon Dec 11 10:32:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: ctransformers in /usr/local/lib/python3.10/dist-packages (0.2.27)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from ctransformers) (0.19.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2023.11.17)

# %%
# !pip install accelerate
# !pip install -U git+https://github.com/huggingface/accelerate.git
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Collecting git+https://github.com/huggingface/accelerate.git
#   Cloning https://github.com/huggingface/accelerate.git to /tmp/pip-req-build-qqtfoyy6
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate.git /tmp/pip-req-build-qqtfoyy6
#   Resolved https://github.com/huggingface/accelerate.git to commit 9964f90fd7d50577998a22f3dba8590e644d255b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.25.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.25.0.dev0) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.25.0.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.25.0.dev0) (1.3.0)
# Building wheels for collected packages: accelerate
#   Building wheel for accelerate (pyproject.toml) ... done
#   Created wheel for accelerate: filename=accelerate-0.25.0.dev0-py3-none-any.whl size=267070 sha256=20fd2afe0ccfa829ace799526b6e29cd0894ca7c317ecb39101ce512ad8e2dd8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrnoo60x/wheels/9c/a3/1e/47368f9b6575655fe9ee1b6350cfa7d4b0befe66a35f8a8365
# Successfully built accelerate
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.25.0
#     Uninstalling accelerate-0.25.0:
#       Successfully uninstalled accelerate-0.25.0
# Successfully installed accelerate-0.25.0.dev0

# %%
# !pip install pytorch-pretrained-bert
import pytorch_pretrained_bert as ppb
assert 'bert-large-cased' in ppb.modeling.PRETRAINED_MODEL_ARCHIVE_MAP
# Out:
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2.1.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (1.23.5)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (1.33.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (4.66.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (2.1.0)
# Requirement already satisfied: botocore<1.34.0,>=1.33.11 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert) (1.33.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert) (1.0.1)
# Requirement already satisfied: s3transfer<0.9.0,>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert) (0.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (2023.11.17)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.11->boto3->pytorch-pretrained-bert) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.1->pytorch-pretrained-bert) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->pytorch-pretrained-bert) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.0,>=1.33.11->boto3->pytorch-pretrained-bert) (1.16.0)

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
import openai
import os
import pandas as pd

# %%
sheet_id = "1N8oZ6XYKFeWbAwTr13yCSxbKu6eo-iKsYH3-IJ5Uuuk"
sheet_name = "Sheet1"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df=pd.read_csv(url)

# %%
# This list will contain the list of all queries
queries=[]
for query in df['Prompt']:
  queries.append(query)

# %%
openai.api_key="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"
model1="gpt-3.5-turbo"

# %% [markdown]
# ### Model-1 gpt-3.5

# %%
def get_tools(query):
  system_prompt = """ Find the tools that would be useful to answer the following query. The available tools and their uses are as follows:
  [
    'works_list':'returns a list of work-items matching the request',
    'summarize_objects':'summarizes a list of objects',
    'prioritize_objects':'sorts a list of objects by priority',
    'add_work_items_to_sprint':'Adds given work items to a sprint',
    'get_sprint_id':'Returns id of the current sprint',
    'get_similar_work_items':'Returns work items similar to the given work item',
    'search_object_by_name':'given a string, returns id of a matching object',
    'create_actionable_tasks_from_text':'Given a text, extracts actionable tasks',
    'who_am_i':'Returns id of the current user',
  ]
  Your answer should only compose of one or more of these tools. Any extra tool or text will be penalized. Return the tools enclosed in [ ].
  Given query is """

  user_prompt = f""": {query} : """

  final_prompt = system_prompt + "\n" + user_prompt
  messages=[{
      "role":"user",
      "content":final_prompt
  }]

  responses=openai.ChatCompletion.create(
      model=model1,
      messages=messages,
      temperature=0
  )

  return responses.choices[0].message['content']

# %%
# unit testing of get_tools function:
tool_results=[]
for query in queries:
  input_string=get_tools(query)
  tool_results.append(input_string)

# %%
def convert_string_to_list(string):
  """
  Converts a string in the format of a list to a list of strings.

  Args:
    string: The string to convert.

  Returns:
    A list of strings.
  """
  # Remove any leading and trailing spaces
  string = string.strip()

  # Check if the string starts and ends with square brackets
  if not string.startswith('[') or not string.endswith(']'):
    raise ValueError('Invalid string format. Expected format: [item1, item2, ...]')

  # Remove the square brackets
  string = string[1:-1]

  # Split the string by commas and strip any whitespace around each item
  items = [item.strip() for item in string.split(',')]

  return items

# %%
def analyze_query(tools_list, query_text):
    tools_purpose = {
        'works_list': 'Returns a list of objects matching the request',
        'summarize_objects': 'Summarizes a list of objects',
        'prioritize_objects': 'Returns a list of objects sorted by priority',
        'add_work_items_to_sprint':'Adds the given objects to the sprint',
        'get_sprint_id':'Return the id of the current sprint',
        'get_similar_work_items':'Returns a list of objects that are similar to the given object',
        'search_object_by_name':'Given a search string, returns the id of a matching object in the system of record',
        'create_actionable_tasks_from_text':'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item',
        'who_am_i':'Returns string_id of current user'
    }

    tools_arguments = {
        'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response','ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types' ],
        'summarize_objects': ['objects: List of object ids to summarize'],
        'prioritize_objects': ['objects: List of objects to prioritize'],
        'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint'],
        'get_sprint_id': [],
        'get_similar_work_items': ['work_id: id of work item to find similar items to'],
        'search_object_by_name': ['query: String to search for'],
        'create_actionable_tasks_from_text': ['text: Text to create actionable tasks from'],
        'who_am_i': []
    }

    relevant_purposes = {tool: tools_purpose[tool] for tool in tools_list if tool in tools_purpose}
    relevant_arguments = {tool: tools_arguments[tool] for tool in tools_list if tool in tools_arguments}

    output_string = f"The given query utilizes the following tools: {tools_list}. "
    output_string += f"The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {relevant_arguments}. "
    output_string += f"The purpose of the tools is as follows: {relevant_purposes}. "
    output_string +="Note that the words issues, objects and work_items have been used interchangably"
    output_string += f"Find the values arguments for the given tools from the following text:\\ {query_text} \\"
    output_string += "Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments."

    return output_string

# %%
arg_prompts=[]
for i in range(0,len(tool_results)):
  # convert string to list of tools
  tools_list=convert_string_to_list(tool_results[i])
  final_prompt=analyze_query(tools_list,queries[i]);
  arg_prompts.append(final_prompt)

# %%
arg_prompts
# Out:
# ["The given query utilizes the following tools: ['works_list', 'get_similar_work_items', 'summarize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'get_similar_work_items': ['work_id: id of work item to find similar items to'], 'summarize_objects': ['objects: List of object ids to summarize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'get_similar_work_items': 'Returns a list of objects that are similar to the given object', 'summarize_objects': 'Summarizes a list of objects'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize work items similar to don:core:dvrv-us-1:devo/0:issue/1 \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Retrieve and summarize the status updates for all user stories assigned to the team member Jane Doe in the last sprint \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'get_sprint_id', 'prioritize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'get_sprint_id': [], 'prioritize_objects': ['objects: List of objects to prioritize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'get_sprint_id': 'Return the id of the current sprint', 'prioritize_objects': 'Returns a list of objects sorted by priority'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Extract and compile a list of tasks completed during the current sprint of project devtest \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  'The given query utilizes the following tools: [\'works_list\', \'summarize_objects\', \'get_sprint_id\', \'search_object_by_name\', \'create_actionable_tasks_from_text\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'get_sprint_id\': [], \'search_object_by_name\': [\'query: String to search for\'], \'create_actionable_tasks_from_text\': [\'text: Text to create actionable tasks from\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'summarize_objects\': \'Summarizes a list of objects\', \'get_sprint_id\': \'Return the id of the current sprint\', \'search_object_by_name\': \'Given a search string, returns the id of a matching object in the system of record\', \'create_actionable_tasks_from_text\': \'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize the issues tagged with "Security" in the current sprint and recommend actions to resolve them \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'works_list\', \'summarize_objects\', \'get_sprint_id\', \'search_object_by_name\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'get_sprint_id\': [], \'search_object_by_name\': [\'query: String to search for\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'summarize_objects\': \'Summarizes a list of objects\', \'get_sprint_id\': \'Return the id of the current sprint\', \'search_object_by_name\': \'Given a search string, returns the id of a matching object in the system of record\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize all tasks listed with "UI/UX" in the current sprint \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'get_similar_work_items\', \'summarize_objects\', \'prioritize_objects\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'get_similar_work_items\': [\'work_id: id of work item to find similar items to\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\']}. The purpose of the tools is as follows: {\'get_similar_work_items\': \'Returns a list of objects that are similar to the given object\', \'summarize_objects\': \'Summarizes a list of objects\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Get work items similar to "DEV", summarize and prioritize them  \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'works_list\', \'prioritize_objects\', \'get_sprint_id\', \'search_object_by_name\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\'], \'get_sprint_id\': [], \'search_object_by_name\': [\'query: String to search for\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\', \'get_sprint_id\': \'Return the id of the current sprint\', \'search_object_by_name\': \'Given a search string, returns the id of a matching object in the system of record\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Prioritize tasks associated with "Internal" in the current spring backlog \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'create_actionable_tasks_from_text\', \'add_work_items_to_sprint\', \'summarize_objects\', \'prioritize_objects\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'create_actionable_tasks_from_text\': [\'text: Text to create actionable tasks from\'], \'add_work_items_to_sprint\': [\'work_ids: List of objects to be added\', \'sprint_id: Id of the sprint\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\']}. The purpose of the tools is as follows: {\'create_actionable_tasks_from_text\': \'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item\', \'add_work_items_to_sprint\': \'Adds the given objects to the sprint\', \'summarize_objects\': \'Summarizes a list of objects\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Given a customer transcript "text", create work items, add them to the current sprint, summarize and prioritize them \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  "The given query utilizes the following tools: ['get_similar_work_items', 'summarize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'get_similar_work_items': ['work_id: id of work item to find similar items to'], 'summarize_objects': ['objects: List of object ids to summarize']}. The purpose of the tools is as follows: {'get_similar_work_items': 'Returns a list of objects that are similar to the given object', 'summarize_objects': 'Summarizes a list of objects'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Search work items similar to user/ref:issue and summarize them \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects', 'prioritize_objects', 'search_object_by_name', 'who_am_i']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize'], 'prioritize_objects': ['objects: List of objects to prioritize'], 'search_object_by_name': ['query: String to search for'], 'who_am_i': []}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects', 'prioritize_objects': 'Returns a list of objects sorted by priority', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record', 'who_am_i': 'Returns string_id of current user'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize and prioritize issues of P0 for user Harry  \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'prioritize_objects', 'add_work_items_to_sprint', 'search_object_by_name', 'who_am_i']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'prioritize_objects': ['objects: List of objects to prioritize'], 'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint'], 'search_object_by_name': ['query: String to search for'], 'who_am_i': []}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'prioritize_objects': 'Returns a list of objects sorted by priority', 'add_work_items_to_sprint': 'Adds the given objects to the sprint', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record', 'who_am_i': 'Returns string_id of current user'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Find the task assigned to user Mark and add it to the current sprint \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'prioritize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'prioritize_objects': ['objects: List of objects to prioritize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'prioritize_objects': 'Returns a list of objects sorted by priority'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Prioritize all the tasks for the rev organization SigmaSquad which have a high severity ticket \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Get work items that I have created and summarize them \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects', 'prioritize_objects', 'search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize'], 'prioritize_objects': ['objects: List of objects to prioritize'], 'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects', 'prioritize_objects': 'Returns a list of objects sorted by priority', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize and prioritize the issues under the triage stage for the rev organization Ajin and the P0 priority issues for the rev organization Kalidas \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['create_actionable_tasks_from_text', 'search_object_by_name', 'add_work_items_to_sprint']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'create_actionable_tasks_from_text': ['text: Text to create actionable tasks from'], 'search_object_by_name': ['query: String to search for'], 'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint']}. The purpose of the tools is as follows: {'create_actionable_tasks_from_text': 'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record', 'add_work_items_to_sprint': 'Adds the given objects to the sprint'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Given the text T detailing the recent team meeting, create a list of tasks. Get a list of tickets coming in from discord from a customer Raja. Add the common tasks to the current sprint. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  'The given query utilizes the following tools: [\'works_list\', \'summarize_objects\', \'prioritize_objects\', \'get_sprint_id\', \'search_object_by_name\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\'], \'get_sprint_id\': [], \'search_object_by_name\': [\'query: String to search for\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'summarize_objects\': \'Summarizes a list of objects\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\', \'get_sprint_id\': \'Return the id of the current sprint\', \'search_object_by_name\': \'Given a search string, returns the id of a matching object in the system of record\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarize and prioritize tasks labeled "Backend" from the last two sprints in the project codehub and give recommendations to resolve them \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'create_actionable_tasks_from_text\', \'search_object_by_name\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'create_actionable_tasks_from_text\': [\'text: Text to create actionable tasks from\'], \'search_object_by_name\': [\'query: String to search for\']}. The purpose of the tools is as follows: {\'create_actionable_tasks_from_text\': \'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item\', \'search_object_by_name\': \'Given a search string, returns the id of a matching object in the system of record\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Delve into the cosmic ponderings: Explore and compare diverse cultural and scientific perspectives on the question, "What is the nature of existence?" \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'get_similar_work_items\', \'summarize_objects\', \'prioritize_objects\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'get_similar_work_items\': [\'work_id: id of work item to find similar items to\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\']}. The purpose of the tools is as follows: {\'get_similar_work_items\': \'Returns a list of objects that are similar to the given object\', \'summarize_objects\': \'Summarizes a list of objects\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Retrieve and distill all work items similar to "BUG-456," synthesize them into coherent issues, and prioritize them for immediate resolution. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ What are the issues for the REV(customer) N V? Summarize them. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects', 'add_work_items_to_sprint']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize'], 'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects', 'add_work_items_to_sprint': 'Adds the given objects to the sprint'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Analyze the minutes from the latest team meeting, generate a task list, and add them to the current sprint. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  'The given query utilizes the following tools: [\'works_list\', \'summarize_objects\', \'prioritize_objects\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'summarize_objects\': \'Summarizes a list of objects\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Extract work tasks with the keyword "Analytics", summarize them, and arrange them by priority. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
# ...
#  "The given query utilizes the following tools: ['create_actionable_tasks_from_text', 'search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'create_actionable_tasks_from_text': ['text: Text to create actionable tasks from'], 'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'create_actionable_tasks_from_text': 'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Send an email to the IT department detailing recent technical challenges faced during project completion and request assistance. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['works_list', 'search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Give a list of my replies in respone to the email related to the finance meeting. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  'The given query utilizes the following tools: ["\'prioritize_objects\'", "\'add_work_items_to_sprint\'"]. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {}. The purpose of the tools is as follows: {}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Organize and prioritize P1 issues, then seamlessly integrate them into the ongoing sprint. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  "The given query utilizes the following tools: ['works_list', 'summarize_objects', 'prioritize_objects', 'add_work_items_to_sprint', 'search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response', 'ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types'], 'summarize_objects': ['objects: List of object ids to summarize'], 'prioritize_objects': ['objects: List of objects to prioritize'], 'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint'], 'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'works_list': 'Returns a list of objects matching the request', 'summarize_objects': 'Summarizes a list of objects', 'prioritize_objects': 'Returns a list of objects sorted by priority', 'add_work_items_to_sprint': 'Adds the given objects to the sprint', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarise the task coming from the Microsoft Team and coming from the Zoom and add them to sprint. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['summarize_objects', 'search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'summarize_objects': ['objects: List of object ids to summarize'], 'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'summarize_objects': 'Summarizes a list of objects', 'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Give comments on the ICC World Cup final between India and Australia. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  "The given query utilizes the following tools: ['search_object_by_name']. The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {'search_object_by_name': ['query: String to search for']}. The purpose of the tools is as follows: {'search_object_by_name': 'Given a search string, returns the id of a matching object in the system of record'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Who is the new chief minister of Andhra Pradesh state? \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.",
#  'The given query utilizes the following tools: ["\'summarize_objects\'", "\'prioritize_objects\'", "\'search_object_by_name\'"]. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {}. The purpose of the tools is as follows: {}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Provide an overview and prioritize critical issues for the organization "Pinnacle" and high-priority tasks for the organization "Skyward". \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'get_similar_work_items\', \'prioritize_objects\', \'summarize_objects\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'get_similar_work_items\': [\'work_id: id of work item to find similar items to\'], \'prioritize_objects\': [\'objects: List of objects to prioritize\'], \'summarize_objects\': [\'objects: List of object ids to summarize\']}. The purpose of the tools is as follows: {\'get_similar_work_items\': \'Returns a list of objects that are similar to the given object\', \'prioritize_objects\': \'Returns a list of objects sorted by priority\', \'summarize_objects\': \'Summarizes a list of objects\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Retrieve and prioritize work items similar to "User Story:123" and summarize their status \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.',
#  'The given query utilizes the following tools: [\'works_list\', \'summarize_objects\', \'add_work_items_to_sprint\']. The arguments of the tools and their description  is as follows. Format is \'argument_name:Purpose of argument\': {\'works_list\': [\'applies_to_part: Array of strings to filter works relevant to\', \'created_by: Takes array of strings and filters work created by users in the array\', \'issue.priority: Array of strings to filter issues with given priorites in the array\', \'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array\', \'limit: integer providing the maximum number of works to return\', \'owned_by: Array of strings to filter issues owned by users specified in the array\', \'stage.name: Array of strings to filter work in the stages provided in the array\', \'ticket.needs_response: Boolean value telling if a ticket needs a response\', \'ticket.rev_org: Array of strings to return tickets associated with the given strings\', \'ticket.severity: Array of strings to filter issues with given severity in the array\', \'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array\', \'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types\'], \'summarize_objects\': [\'objects: List of object ids to summarize\'], \'add_work_items_to_sprint\': [\'work_ids: List of objects to be added\', \'sprint_id: Id of the sprint\']}. The purpose of the tools is as follows: {\'works_list\': \'Returns a list of objects matching the request\', \'summarize_objects\': \'Summarizes a list of objects\', \'add_work_items_to_sprint\': \'Adds the given objects to the sprint\'}. Note that the words issues, objects and work_items have been used interchangablyFind the values arguments for the given tools from the following text:\\ Summarise all the problem statements of the "Inter IIT Tech Meet 12.0" and add them to sprint. \\Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments.']

# %%
model2="gpt-4"

# %%
def get_arguments(formatted_prompt):
  messages=[{
      "role":"user",
      "content":formatted_prompt
  }]

  responses=openai.ChatCompletion.create(
      model=model2,
      messages=messages,
      temperature=0
  )

  return responses.choices[0].message['content']

# %%
argument_predictions=[]
for prompt in arg_prompts:
  arg=get_arguments(prompt);
  argument_predictions.append(arg)

# %%
for arg in argument_predictions:
  print(arg)
  print('\n')
# Out:
# {
#   "get_similar_work_items": {
#     "work_id": "don:core:dvrv-us-1:devo/0:issue/1"
#   },
#   "summarize_objects": {
#     "objects": "$$PREV[0]"
#   }
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "owned_by",
#       "argument_value": ["Jane Doe"]
#     },
#     {
#       "argument_name": "type",
#       "argument_value": ["user story"]
#     },
#     {
#       "argument_name": "stage.name",
#       "argument_value": ["last sprint"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
#
#
# The text does not provide specific values for the arguments of the mentioned tools. However, based on the context, we can infer potential values for some arguments. Here is a possible interpretation:
#
# ```json
# {
#   "works_list": [
#     {
#       "argument_name": "type",
#       "argument_value": ["task"]
#     },
#     {
#       "argument_name": "stage.name",
#       "argument_value": ["completed"]
#     }
#   ],
#   "get_sprint_id": [],
#   "prioritize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
# ```
#
# In this interpretation, we are assuming that the tasks completed during the current sprint are of type "task" and are in the "completed" stage. The output of the `works_list` tool (the list of completed tasks) is then used as the input for the `prioritize_objects` tool.
#
#
# {
#   "works_list": {
#     "applies_to_part": [],
#     "created_by": [],
#     "issue.priority": [],
#     "issue.rev_orgs": [],
#     "limit": [],
#     "owned_by": [],
#     "stage.name": [],
#     "ticket.needs_response": [],
#     "ticket.rev_org": [],
#     "ticket.severity": [],
#     "ticket.source_channel": [],
#     "type": ["issue"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "get_sprint_id": {},
#   "search_object_by_name": {
#     "query": ["Security"]
#   },
#   "create_actionable_tasks_from_text": {
#     "text": ["$$PREV[1]"]
#   }
# }
#
#
# {
#   "works_list": {
#     "applies_to_part": [],
#     "created_by": [],
#     "issue.priority": [],
#     "issue.rev_orgs": [],
#     "limit": [],
#     "owned_by": [],
#     "stage.name": [],
#     "ticket.needs_response": [],
#     "ticket.rev_org": [],
#     "ticket.severity": [],
#     "ticket.source_channel": [],
#     "type": ["task"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "get_sprint_id": {},
#   "search_object_by_name": {
#     "query": ["UI/UX"]
#   }
# }
#
#
# {
# "get_similar_work_items":
#     {
#         "work_id": "DEV"
#     },
# "summarize_objects":
#     {
#         "objects": "$$PREV[0]"
#     },
# "prioritize_objects":
#     {
#         "objects": "$$PREV[1]"
#     }
# }
#
#
# {
#   "works_list": {
#     "applies_to_part": ["Internal"],
#     "stage.name": ["backlog"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "get_sprint_id": {},
#   "search_object_by_name": {
#     "query": ["tasks"]
#   }
# }
#
#
# {
#   "create_actionable_tasks_from_text": {
#     "text": "Given a customer transcript \"text\""
#   },
#   "add_work_items_to_sprint": {
#     "work_ids": "$$PREV[0]",
#     "sprint_id": "current sprint"
#   },
#   "summarize_objects": {
#     "objects": "$$PREV[1]"
#   },
#   "prioritize_objects": {
#     "objects": "$$PREV[2]"
#   }
# }
#
#
# {
# "get_similar_work_items":
#     {
#         "work_id": "user/ref:issue"
#     },
# "summarize_objects":
#     {
#         "objects": "$$PREV[0]"
#     }
# }
#
#
# {
#   "works_list": {
#     "issue.priority": ["P0"],
#     "owned_by": ["Harry"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[1]"]
#   },
#   "who_am_i": {}
# }
#
#
# {
#   "works_list": {
#     "owned_by": ["Mark"],
#     "type": ["task"]
#   },
#   "search_object_by_name": {
#     "query": "$$PREV[0]"
#   },
#   "who_am_i": {},
#   "add_work_items_to_sprint": {
#     "work_ids": ["$$PREV[1]"],
#     "sprint_id": "$$PREV[2]"
#   }
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "type",
#       "argument_value": ["task"]
#     },
#     {
#       "argument_name": "ticket.rev_org",
#       "argument_value": ["SigmaSquad"]
#     },
#     {
#       "argument_name": "ticket.severity",
#       "argument_value": ["high"]
#     }
#   ],
#   "prioritize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "created_by",
#       "argument_value": ["I"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "stage.name",
#       "argument_value": ["triage"]
#     },
#     {
#       "argument_name": "issue.rev_orgs",
#       "argument_value": ["Ajin", "Kalidas"]
#     },
#     {
#       "argument_name": "issue.priority",
#       "argument_value": ["P0"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ],
#   "prioritize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[1]"]
#     }
#   ]
# }
#
#
# {
#   "create_actionable_tasks_from_text": [
#     {
#       "argument_name": "text",
#       "argument_value": "Given the text T detailing the recent team meeting, create a list of tasks."
#     }
#   ],
#   "search_object_by_name": [
#     {
#       "argument_name": "query",
#       "argument_value": "Get a list of tickets coming in from discord from a customer Raja."
#     }
#   ],
#   "add_work_items_to_sprint": [
#     {
#       "argument_name": "work_ids",
#       "argument_value": "$$PREV[0], $$PREV[1]"
#     },
#     {
#       "argument_name": "sprint_id",
#       "argument_value": "current sprint"
#     }
#   ]
# }
#
#
# {
#   "works_list": {
#     "applies_to_part": ["Backend"],
#     "type": ["task"]
#   },
#   "get_sprint_id": {},
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[1]"]
#   },
#   "search_object_by_name": {
#     "query": ["codehub"]
#   }
# }
#
#
# {
#   "create_actionable_tasks_from_text": {
#     "text": "Delve into the cosmic ponderings: Explore and compare diverse cultural and scientific perspectives on the question, \"What is the nature of existence?\""
#   },
#   "search_object_by_name": {
#     "query": "What is the nature of existence?"
#   }
# }
#
#
# {
#   "get_similar_work_items": {
#     "work_id": "BUG-456"
#   },
#   "summarize_objects": {
#     "objects": "$$PREV[0]"
#   },
#   "prioritize_objects": {
#     "objects": "$$PREV[1]"
#   }
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "issue.rev_orgs",
#       "argument_value": ["REV(customer) N V"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
#
#
# The text does not provide specific values for the arguments of the mentioned tools.
#
#
# {
#   "works_list": {
#     "applies_to_part": ["Analytics"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[1]"]
#   }
# }
#
#
# {
#   "create_actionable_tasks_from_text": [
#     {
#       "argument_name": "text",
#       "argument_value": "Reflect on the concept of time"
#     }
#   ]
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "ticket.source_channel",
#       "argument_value": ["Microsoft Teams"]
#     },
#     {
#       "argument_name": "owned_by",
#       "argument_value": ["Rahul"]
#     },
#     {
#       "argument_name": "ticket.severity",
#       "argument_value": ["high-impact"]
#     },
#     {
#       "argument_name": "type",
#       "argument_value": ["ticket"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ]
# }
#
#
# The text provided does not contain any values for the relevant arguments of the mentioned tool 'search_object_by_name'.
#
#
# {
#   "works_list": {
#     "created_by": ["me"],
#     "ticket.severity": ["high"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   }
# }
#
#
# {
#   "works_list": {
#     "issue.priority": ["urgent"],
#     "type": ["email"]
#   },
#   "summarize_objects": {
#     "objects": "$$PREV[0]"
#   }
# }
#
#
# {
#   "search_object_by_name": {
#     "query": "admin"
#   },
#   "create_actionable_tasks_from_text": {
#     "text": "send an email to admin about the problems encountered during completion of tasks"
#   }
# }
#
#
# {
# "get_similar_work_items":
#     {
#         "work_id": "Null Pointer Exception in Module"
#     },
# "prioritize_objects":
#     {
#         "objects": "$$PREV[0]"
#     }
# }
#
#
# {
#   "search_object_by_name": [
#     {
#       "argument_name": "query",
#       "argument_value": "Backend Refactoring"
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": "$$PREV[0]"
#     }
#   ],
#   "add_work_items_to_sprint": [
#     {
#       "argument_name": "work_ids",
#       "argument_value": "$$PREV[1]"
#     },
#     {
#       "argument_name": "sprint_id",
#       "argument_value": "current sprint"
#     }
#   ]
# }
#
#
# {
#   "create_actionable_tasks_from_text": [
#     {
#       "argument_name": "text",
#       "argument_value": "Implement the payment gateway and test the checkout flow"
#     }
#   ],
#   "prioritize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": "$$PREV[0]"
#     }
#   ],
#   "add_work_items_to_sprint": [
#     {
#       "argument_name": "work_ids",
#       "argument_value": "$$PREV[1]"
#     },
#     {
#       "argument_name": "sprint_id",
#       "argument_value": "$$PREV[3]"
#     }
#   ],
#   "get_sprint_id": []
# }
#
#
# {
#   "search_object_by_name": [
#     {
#       "argument_name": "query",
#       "argument_value": "API Development"
#     }
#   ]
# }
#
#
# The text does not provide any specific values for the arguments of the tools. Therefore, it is not possible to extract any argument values from the given text.
#
#
# {
#   "search_object_by_name": {
#     "argument_name": "query",
#     "argument_value": "Oppenheimer"
#   },
#   "get_similar_work_items": {
#     "argument_name": "work_id",
#     "argument_value": "$$PREV[0]"
#   }
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "limit",
#       "argument_value": 30
#     },
#     {
#       "argument_name": "ticket.source_channel",
#       "argument_value": ["email"]
#     },
#     {
#       "argument_name": "owned_by",
#       "argument_value": ["me"]
#     },
#     {
#       "argument_name": "ticket.needs_response",
#       "argument_value": true
#     },
#     {
#       "argument_name": "type",
#       "argument_value": ["ticket"]
#     },
#     {
#       "argument_name": "ticket.rev_org",
#       "argument_value": ["Gemini"]
#     }
#   ]
# }
#
#
# {
#   "works_list": {
#     "applies_to_part": ["INS69"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "create_actionable_tasks_from_text": {
#     "text": ["$$PREV[1]"]
#   }
# }
#
#
# {
#   "works_list": {
#     "applies_to_part": ["Navishkar"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "add_work_items_to_sprint": {
#     "work_ids": ["$$PREV[1]"],
#     "sprint_id": ["$$PREV[2]"]
#   },
#   "get_sprint_id": {}
# }
#
#
# {
#   "works_list": [
#     {
#       "argument_name": "ticket.severity",
#       "argument_value": ["blocker"]
#     },
#     {
#       "argument_name": "issue.priority",
#       "argument_value": ["P0"]
#     },
#     {
#       "argument_name": "ticket.rev_org",
#       "argument_value": ["Llama", "Falcon"]
#     },
#     {
#       "argument_name": "issue.rev_orgs",
#       "argument_value": ["Llama", "Falcon"]
#     },
#     {
#       "argument_name": "type",
#       "argument_value": ["ticket", "issue"]
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[0]"]
#     }
#   ],
#   "prioritize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": ["$$PREV[1]"]
#     }
#   ]
# }
#
#
# {
#   "get_similar_work_items": [
#     {
#       "argument_name": "work_id",
#       "argument_value": "Finetuning GPT-3.5-Turbo"
#     }
#   ],
#   "summarize_objects": [
#     {
#       "argument_name": "objects",
#       "argument_value": "$$PREV[0]"
#     }
#   ]
# }
#
#
# {
#   "works_list": {
#     "owned_by": ["me"],
#     "type": ["task"]
#   },
#   "add_work_items_to_sprint": {
#     "work_ids": ["$$PREV[0]"]
#   },
#   "search_object_by_name": {
#     "query": ["URGENT"]
#   }
# }
#
#
# {
#   "create_actionable_tasks_from_text": {
#     "text": "Send an email to the IT department detailing recent technical challenges faced during project completion and request assistance."
#   },
#   "search_object_by_name": {
#     "query": ""
#   }
# }
#
#
# The text does not provide enough information to extract values for the arguments of the given tools.
#
#
# The text does not provide enough information to identify the values of the arguments for the given tools.
#
#
# {
#   "works_list": {
#     "ticket.source_channel": ["Microsoft Team", "Zoom"],
#     "type": ["task"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[0]"]
#   },
#   "add_work_items_to_sprint": {
#     "work_ids": ["$$PREV[1]"],
#     "sprint_id": null
#   }
# }
#
#
# {
#   "search_object_by_name": {
#     "argument_name": "query",
#     "argument_value": "ICC World Cup final between India and Australia"
#   },
#   "summarize_objects": {
#     "argument_name": "objects",
#     "argument_value": "$$PREV[0]"
#   }
# }
#
#
# {"search_object_by_name": {"argument_name": "query", "argument_value": "new chief minister of Andhra Pradesh state"}}
#
#
# {
#   "summarize_objects": {
#     "organization_name": "Pinnacle"
#   },
#   "prioritize_objects": {
#     "organization_name": "Pinnacle"
#   },
#   "search_object_by_name": {
#     "organization_name": "Skyward"
#   }
# }
#
#
# {
#   "get_similar_work_items": {
#     "work_id": "User Story:123"
#   },
#   "prioritize_objects": {
#     "objects": "$$PREV[0]"
#   },
#   "summarize_objects": {
#     "objects": "$$PREV[1]"
#   }
# }
#
#
# The text does not provide enough specific information to extract the values for the arguments of the given tools.

# %%
''' Now, we have 3 lists: queries, tool_results and argument_predictions.
We can summarize them into a CSV '''
data={'query':queries, 'tools':tool_results, 'arguments':argument_predictions}
df=pd.DataFrame(data)
df.to_csv('resultIB03_base.csv')
