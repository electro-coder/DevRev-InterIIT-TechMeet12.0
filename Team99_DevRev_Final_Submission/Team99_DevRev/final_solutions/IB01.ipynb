# %%
''' This notebook contains the following:
    M1 - GPT 4
    M2 - GPT 4
    Both the models are unfinetuned
'''
# !pip install openai==0.28
# !nvidia-smi
# !pip install pandas
# !CT_CUBLAS=1 pip install ctransformers --no-binary ctransformers
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.0
# Tue Dec 12 05:26:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting ctransformers
#   Downloading ctransformers-0.2.27.tar.gz (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.1/376.1 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from ctransformers) (0.19.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->ctransformers) (2023.11.17)
# Building wheels for collected packages: ctransformers
#   Building wheel for ctransformers (pyproject.toml) ... done
#   Created wheel for ctransformers: filename=ctransformers-0.2.27-cp310-cp310-linux_x86_64.whl size=2338812 sha256=02b8b1a9a58f4af16b8196f46ea516e95f86a79c3780d1a5bc38e8386f3f0741
#   Stored in directory: /root/.cache/pip/wheels/dd/54/e9/32364da8eee84a2b0b412394983c15add18816c507e90f02d8
# Successfully built ctransformers
# Installing collected packages: ctransformers
# Successfully installed ctransformers-0.2.27

# %%
# !pip install accelerate
# !pip install -U git+https://github.com/huggingface/accelerate.git
# Out:
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0
# Collecting git+https://github.com/huggingface/accelerate.git
#   Cloning https://github.com/huggingface/accelerate.git to /tmp/pip-req-build-zarjch1j
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate.git /tmp/pip-req-build-zarjch1j
#   Resolved https://github.com/huggingface/accelerate.git to commit eafcea07f639a5476385854ea9bccdbba467db9d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0.dev0) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.25.0.dev0) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.25.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.25.0.dev0) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.25.0.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.25.0.dev0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.25.0.dev0) (1.3.0)
# Building wheels for collected packages: accelerate
#   Building wheel for accelerate (pyproject.toml) ... done
#   Created wheel for accelerate: filename=accelerate-0.25.0.dev0-py3-none-any.whl size=267226 sha256=560690f6979489901e058e854b3255de4b1e8caad62d012726dd9e1128e000cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5ddqy80x/wheels/9c/a3/1e/47368f9b6575655fe9ee1b6350cfa7d4b0befe66a35f8a8365
# Successfully built accelerate
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.25.0
#     Uninstalling accelerate-0.25.0:
#       Successfully uninstalled accelerate-0.25.0
# Successfully installed accelerate-0.25.0.dev0

# %%
# !pip install pytorch-pretrained-bert
import pytorch_pretrained_bert as ppb
assert 'bert-large-cased' in ppb.modeling.PRETRAINED_MODEL_ARCHIVE_MAP
# Out:
# Collecting pytorch-pretrained-bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2.1.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (1.23.5)
# Collecting boto3 (from pytorch-pretrained-bert)
#   Downloading boto3-1.33.12-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (4.66.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (2.1.0)
# Collecting botocore<1.34.0,>=1.33.12 (from boto3->pytorch-pretrained-bert)
#   Downloading botocore-1.33.12-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 31.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-pretrained-bert)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3->pytorch-pretrained-bert)
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert) (2023.11.17)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.12->boto3->pytorch-pretrained-bert) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.1->pytorch-pretrained-bert) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->pytorch-pretrained-bert) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.0,>=1.33.12->boto3->pytorch-pretrained-bert) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3, pytorch-pretrained-bert
# Successfully installed boto3-1.33.12 botocore-1.33.12 jmespath-1.0.1 pytorch-pretrained-bert-0.6.2 s3transfer-0.8.2

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 35.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.4 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.7 MB/s eta 0:00:00

# %%
import openai
import os
import pandas as pd

# %%
''' Code to take queries from CSV '''
# sheet_id = "1N8oZ6XYKFeWbAwTr13yCSxbKu6eo-iKsYH3-IJ5Uuuk"
# sheet_name = "Sheet1"
# url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
df=pd.read_csv(url)

# %%
queries=[] # This list will contain the list of all queries. Please add your queries here.
for query in df['Prompt']:
  queries.append(query)

# %%
openai.api_key="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"
model="gpt-4"

# %%
# To add a new tool, edit the prompts in this function.
def get_tools(query):
  system_prompt = """ Find the tools that would be useful to answer the following query. The available tools and their uses are as follows:
  [
    'works_list':'returns a list of work-items matching the request',
    'summarize_objects':'summarizes a list of objects',
    'prioritize_objects':'sorts a list of objects by priority',
    'add_work_items_to_sprint':'Adds given work items to a sprint',
    'get_sprint_id':'Returns id of the current sprint',
    'get_similar_work_items':'Returns work items similar to the given work item',
    'search_object_by_name':'given a string, returns id of a matching object',
    'create_actionable_tasks_from_text':'Given a text, extracts actionable tasks',
    'who_am_i':'Returns id of the current user',
  ]
  Your answer should only compose of one or more of these tools. Any extra tool or text will be penalized. Return the tools enclosed in [ ].
  Given query is """

  user_prompt = f""": {query} : """

  final_prompt = system_prompt + "\n" + user_prompt
  messages=[{
      "role":"user",
      "content":final_prompt
  }]

  responses=openai.ChatCompletion.create(
      model=model,
      messages=messages,
      temperature=0
  )

  return responses.choices[0].message['content']

# %%
tool_results=[]
for query in queries:
  input_string=get_tools(query)
  tool_results.append(input_string)

# %%
# Conversion of string to list:
import ast

def convert_string_to_list(input_string):
    try:
        # Using ast.literal_eval to safely evaluate the string as a literal expression
        result_list = ast.literal_eval(input_string)
        if isinstance(result_list, list):
            return result_list
        else:
            raise ValueError("Input is not a valid list.")
    except (ValueError, SyntaxError) as e:
        print(f"Error: {e}")
        return None

# %%
# To add a new tool, edit the prompts in this function
def analyze_query(tools_list, query_text):
    tools_purpose = {
        'works_list': 'Returns a list of objects matching the request',
        'summarize_objects': 'Summarizes a list of objects',
        'prioritize_objects': 'Returns a list of objects sorted by priority',
        'add_work_items_to_sprint':'Adds the given objects to the sprint',
        'get_sprint_id':'Return the id of the current sprint',
        'get_similar_work_items':'Returns a list of objects that are similar to the given object',
        'search_object_by_name':'Given a search string, returns the id of a matching object in the system of record',
        'create_actionable_tasks_from_text':'Given a text, extracts actionable text The text from which the actionable string insights, and creates tasks for them, which are kind of a work item',
        'who_am_i':'Returns string_id of current user'
    }

    tools_arguments = {
        'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response','ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types' ],
        'summarize_objects': ['objects: List of object ids to summarize'],
        'prioritize_objects': ['objects: List of objects to prioritize'],
        'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint'],
        'get_sprint_id': [],
        'get_similar_work_items': ['work_id: id of work item to find similar items to'],
        'search_object_by_name': ['query: String to search for'],
        'create_actionable_tasks_from_text': ['text: Text to create actionable tasks from'],
        'who_am_i': []
    }

    relevant_purposes = {tool: tools_purpose[tool] for tool in tools_list if tool in tools_purpose}
    relevant_arguments = {tool: tools_arguments[tool] for tool in tools_list if tool in tools_arguments}

    output_string = f"The given query utilizes the following tools: {tools_list}. "
    output_string += f"The arguments of the tools and their description  is as follows. Format is 'argument_name:Purpose of argument': {relevant_arguments}. "
    output_string += f"The purpose of the tools is as follows: {relevant_purposes}. "
    output_string +="Note that the words issues, objects and work_items have been used interchangably"
    output_string += f"Find the values arguments for the given tools from the following text:\\ {query_text} \\"
    output_string += "Just return the value of the arguments, do not return anything else. In case you need to use the output of the previous tool as an input to the next tool, you can name it as $$PREV[i], where i is the index of the tool starting from 0. Return answer in nested JSON format with separate JSONS in one JSON for each tool named after the tool itself. The keys are: argument_name and argument_value. Every argument need not have a value. But every tool taking an argument must take atleast one argument. Only find values for relevant arguments."

    return output_string

# %%
arg_prompts=[]
for i in range(0,len(tool_results)):
  # convert string to list of tools
  tools_list=convert_string_to_list(tool_results[i])
  final_prompt=analyze_query(tools_list,queries[i]);
  arg_prompts.append(final_prompt)

# %%
def get_arguments(formatted_prompt):
  messages=[{
      "role":"user",
      "content":formatted_prompt
  }]

  responses=openai.ChatCompletion.create(
      model=model,
      messages=messages,
      temperature=0
  )

  return responses.choices[0].message['content']

# %%
argument_predictions=[]
for prompt in arg_prompts:
  arg=get_arguments(prompt);
  argument_predictions.append(arg)

# %%
# Uncomment to view the argument predictions
# for arg in argument_predictions:
#   print(arg)
#   print('\n')
# Out:
# {"get_similar_work_items": {"argument_name": "work_id", "argument_value": "don:core:dvrv-us-1:devo/0:issue/1"}, "summarize_objects": {"argument_name": "objects", "argument_value": "$$PREV[0]"}}
#
#
# {
#   "search_object_by_name": {
#     "query": "Harry"
#   },
#   "works_list": {
#     "issue.priority": ["P0"],
#     "owned_by": ["$$PREV[0]"]
#   },
#   "summarize_objects": {
#     "objects": ["$$PREV[1]"]
#   },
#   "prioritize_objects": {
#     "objects": ["$$PREV[2]"]
#   }
# }

# %%
''' Now, we have 3 lists: queries, tool_results and argument_predictions.
We can summarize them into a CSV '''
data={'query':queries, 'tools':tool_results, 'arguments':argument_predictions}
df=pd.DataFrame(data)
df.to_csv('resultIB01_base.csv')

# %%
df
# Out:
#                                                 query  \
# 0   Summarize work items similar to don:core:dvrv-...
# 1   Retrieve and summarize the status updates for ...
# 2   Extract and compile a list of tasks completed ...
# 3   Summarize the issues tagged with "Security" in...
# 4   Summarize all tasks listed with "UI/UX" in the...
# 5   Get work items similar to "DEV", summarize and...
# 6   Prioritize tasks associated with "Internal" in...
# 7   Given a customer transcript "text", create wor...
# 8   Search work items similar to user/ref:issue an...
# 9   Summarize and prioritize issues of P0 for user...
# 10  Find the task assigned to user Mark and add it...
# 11  Prioritize all the tasks for the rev organizat...
# 12  Get work items that I have created and summari...
# 13  Summarize and prioritize the issues under the ...
# 14  Given the text T detailing the recent team mee...
# 15  Summarize and prioritize tasks labeled "Backen...
# 16  Delve into the cosmic ponderings: Explore and ...
# 17  Retrieve and distill all work items similar to...
# 18  What are the issues for the REV(customer) N V?...
# 19  Analyze the minutes from the latest team meeti...
# 20  Extract work tasks with the keyword "Analytics...
# 21                     Reflect on the concept of time
# 22  Compile a detailed list of high-impact tickets...
# 23               Contemplate the meaning of knowledge
# 24  Extract insights from high-severity tickets su...
# 25  Give a list of urgent emails to read and summa...
# 26  send an email to admin about the problems enco...
# 27  Search for the bug reports similar to Null Poi...
# 28  Search for a work item named “Backend Refactor...
# 29  Extract tasks from the text “Implement the pay...
# 30       Find work items related to “API Development”
# 31                 Summarize the current user's tasks
# 32        What do you think of the movie Oppenheimer?
# 33  Give me 30 tickets coming in from Gemini throu...
# 34  Get all the tasks that are a part of INS69, su...
# 35  Search for the works relating to Navishkar and...
# 36  Summarize and prioritize the blocker severity ...
# 37  Get all the tasks that bear a resemblance to "...
# 38  Find all the tasks given to me that needs to b...
# 39  Send an email to the IT department detailing r...
# 40  Give a list of my replies in respone to the em...
# 41  Organize and prioritize P1 issues, then seamle...
# 42  Summarise the task coming from the Microsoft T...
# 43  Give comments on the ICC World Cup final betwe...
# 44  Who is the new chief minister of Andhra Prades...
# 45  Provide an overview and prioritize critical is...
# 46  Retrieve and prioritize work items similar to ...
# 47  Summarise all the problem statements of the "I...
#
#                                                 tools  \
# 0     ['get_similar_work_items', 'summarize_objects']
# 1   ['search_object_by_name', 'get_sprint_id', 'wo...
# 2   ['get_sprint_id', 'works_list', 'summarize_obj...
# 3   ['get_sprint_id', 'works_list', 'summarize_obj...
# 4   ['get_sprint_id', 'works_list', 'summarize_obj...
# 5   ['get_similar_work_items', 'summarize_objects'...
# 6   ['get_sprint_id', 'works_list', 'prioritize_ob...
# 7   ['create_actionable_tasks_from_text', 'add_wor...
# 8     ['get_similar_work_items', 'summarize_objects']
# 9   ['search_object_by_name', 'works_list', 'summa...
# 10  ['search_object_by_name', 'works_list', 'get_s...
# 11               ['works_list', 'prioritize_objects']
# 12    ['works_list', 'who_am_i', 'summarize_objects']
# 13  ['works_list', 'summarize_objects', 'prioritiz...
# 14  ['create_actionable_tasks_from_text', 'works_l...
# 15  ['works_list', 'summarize_objects', 'prioritiz...
# 16              ['create_actionable_tasks_from_text']
# 17  ['get_similar_work_items', 'summarize_objects'...
# 18                ['works_list', 'summarize_objects']
# 19  ['create_actionable_tasks_from_text', 'get_spr...
# 20  ['works_list', 'summarize_objects', 'prioritiz...
# 21              ['create_actionable_tasks_from_text']
# 22  ['search_object_by_name', 'works_list', 'prior...
# 23              ['create_actionable_tasks_from_text']
# 24  ['who_am_i', 'works_list', 'prioritize_objects...
# 25  ['works_list', 'prioritize_objects', 'summariz...
# 26              ['create_actionable_tasks_from_text']
# 27  ['search_object_by_name', 'get_similar_work_it...
# 28  ['search_object_by_name', 'summarize_objects',...
# 29  ['create_actionable_tasks_from_text', 'priorit...
# 30            ['works_list', 'search_object_by_name']
# 31    ['who_am_i', 'works_list', 'summarize_objects']
# 32                                                 []
# 33   ['works_list', 'who_am_i', 'prioritize_objects']
# 34  ['search_object_by_name', 'works_list', 'summa...
# 35  ['search_object_by_name', 'works_list', 'prior...
# 36  ['works_list', 'summarize_objects', 'prioritiz...
# 37    ['get_similar_work_items', 'summarize_objects']
# 38  ['who_am_i', 'works_list', 'search_object_by_n...
# 39              ['create_actionable_tasks_from_text']
# 40            ['works_list', 'search_object_by_name']
# 41  ['works_list', 'prioritize_objects', 'get_spri...
# 42  ['search_object_by_name', 'works_list', 'summa...
# 43                                                 []
# 44                                                 []
# 45  ['search_object_by_name', 'works_list', 'prior...
# 46  ['get_similar_work_items', 'prioritize_objects...
# 47  ['search_object_by_name', 'works_list', 'summa...
#
#                                             arguments
# 0   {\n"get_similar_work_items": \n    {\n        ...
# 1   {\n  "search_object_by_name": {\n    "argument...
# 2   {\n  "get_sprint_id": [\n    {\n      "argumen...
# 3   {\n  "get_sprint_id": [],\n  "works_list": [\n...
# 4   {\n  "get_sprint_id": [],\n  "works_list": [\n...
# 5   {\n"get_similar_work_items": \n    {\n        ...
# 6   {\n  "get_sprint_id": [],\n  "works_list": [\n...
# 7   The values for the arguments for the given too...
# 8   {"get_similar_work_items": {"work_id": "user/r...
# 9   {\n  "search_object_by_name": {\n    "argument...
# 10  {\n  "search_object_by_name": {\n    "argument...
# 11  {\n  "works_list": [\n    {\n      "argument_n...
# 12  The values of the arguments for the given tool...
# 13  {\n  "works_list": [\n    {\n      "argument_n...
# 14  {\n  "create_actionable_tasks_from_text": {\n ...
# 15  {\n  "works_list": {\n    "applies_to_part": [...
# 16  {\n  "create_actionable_tasks_from_text": [\n ...
# 17  {\n  "get_similar_work_items": {\n    "work_id...
# 18  {\n  "works_list": [\n    {\n      "argument_n...
# 19  {\n  "create_actionable_tasks_from_text": {\n ...
# 20  {\n  "works_list": {\n    "applies_to_part": [...
# 21  {\n  "create_actionable_tasks_from_text": [\n ...
# 22  {\n  "search_object_by_name": {\n    "argument...
# 23  {\n  "create_actionable_tasks_from_text": [\n ...
# 24  {\n  "who_am_i": {\n    "arguments": []\n  },\...
# 25  {\n  "works_list": {\n    "issue.priority": ["...
# 26  {\n  "create_actionable_tasks_from_text": [\n ...
# 27  {\n  "search_object_by_name": {\n    "argument...
# 28  {\n  "search_object_by_name": {\n    "query": ...
# 29  {\n  "create_actionable_tasks_from_text": [\n ...
# 30  {\n  "search_object_by_name": [\n    {\n      ...
# 31  The text does not provide any specific values ...
# 32  The text provided does not contain any informa...
# 33  {\n  "works_list": [\n    {\n      "argument_n...
# 34  {\n  "search_object_by_name": [\n    {\n      ...
# 35  {\n  "search_object_by_name": {\n    "argument...
# 36  {\n  "works_list": [\n    {\n      "argument_n...
# 37  {\n"get_similar_work_items": \n    {\n        ...
# 38  {\n  "who_am_i": [],\n  "works_list": [\n    {...
# 39  {\n  "create_actionable_tasks_from_text": [\n ...
# 40  {\n  "works_list": [\n    {\n      "argument_n...
# 41  {\n  "works_list": {\n    "issue.priority": ["...
# 42  {\n  "search_object_by_name": [],\n  "works_li...
# 43  The text does not provide any information abou...
# 44  The text provided does not contain any informa...
# 45  {\n  "search_object_by_name": [\n    {\n      ...
# 46  {\n"get_similar_work_items": \n    {\n        ...
# 47  {\n  "search_object_by_name": {\n    "argument...

# %%
# JSONifier
def generate_json_schema(cell_value):
    prompt = """Convert the following argument cell value to the general JSON schema. If there are specific fields not present. Ignore them.
                  general JSON schema (results may be different):
                  [
                    "tool_name": "tool_name",
                    "arguments": [
                      {
                        "argument_name":"arg_name"
                        "argument_value":"arg_value"
                      }
                    ]
                  ]

                  An example:
                  [
                    {
                      "tool_name": "whoami",
                      "arguments": []
                    },
                    {
                      "tool_name": "works_list",
                      "arguments": [
                        {
                          "argument_name": "issue.priority",
                          "argument_value": ["p0"]
                        },
                        {
                          "argument_name": "owned_by",
                          "argument_value": ["$$PREV[0]"]
                        },
                        {
                          "argument_name": "type",
                          "argument_value": ["issue"]
                        }
                      ]
                    },
                    {
                      "tool_name": "prioritize_objects",
                      "arguments": [
                        {
                          "argument_name": "objects",
                          "argument_value": "$$PREV[1]"
                        }
                      ]
                    },
                    {
                      "tool_name": "get_sprint_id",
                      "arguments": []
                    },
                    {
                      "tool_name": "add_work_items_to_sprint",
                      "arguments": [
                        {
                          "argument_name": "work_ids",
                          "argument_value": "$$PREV[2]"
                        },
                        {
                          "argument_name": "sprint_id",
                          "argument_value": "$$PREV[3]"
                        }
                      ]
                    }
                ]"""
    messages=[{
      "role":"user",
      "content":prompt
  }]

    response=openai.ChatCompletion.create(
      model=model,
      messages=messages,
      temperature=0
  )
    generated_json_schema = response.choices[0].message['content']

    return generated_json_schema

csv_file_path = '/content/resultIB01_base.csv'
df = pd.read_csv(csv_file_path)

df['generated_json_schema'] = df['arguments'].apply(generate_json_schema)

output_csv_path = 'output_file.csv'
df.to_csv(output_csv_path, index=False)

# %%
openai.api_key="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"
model="gpt-3.5-turbo"

# %%
# Recursive Self Optimization Layer
def get_optimized_prompt(query, tools, arguments):
  system_prompt = """ The available tools and their uses are as follows:
  [
    'works_list':'returns a list of work-items matching the request',
    'summarize_objects':'summarizes a list of objects',
    'prioritize_objects':'sorts a list of objects by priority',
    'add_work_items_to_sprint':'Adds given work items to a sprint',
    'get_sprint_id':'Returns id of the current sprint',
    'get_similar_work_items':'Returns work items similar to the given work item',
    'search_object_by_name':'given a string, returns id of a matching object',
    'create_actionable_tasks_from_text':'Given a text, extracts actionable tasks',
    'who_am_i':'Returns id of the current user',
  ]
  Arguments taken by the tools are as follows:

    tools_arguments = {
        'works_list': ['applies_to_part: Array of strings to filter works relevant to', 'created_by: Takes array of strings and filters work created by users in the array', 'issue.priority: Array of strings to filter issues with given priorites in the array', 'issue.rev_orgs: Array of strings to filter issues for the organizations provided in the array', 'limit: integer providing the maximum number of works to return', 'owned_by: Array of strings to filter issues owned by users specified in the array', 'stage.name: Array of strings to filter work in the stages provided in the array', 'ticket.needs_response: Boolean value telling if a ticket needs a response','ticket.rev_org: Array of strings to return tickets associated with the given strings', 'ticket.severity: Array of strings to filter issues with given severity in the array', 'ticket.source_channel: Array of strings to filter for ticklets of the provided channels in the array', 'type: Array of strings with allowed values: [issue, ticket, task] Filters for work of the provided types' ],
        'summarize_objects': ['objects: List of object ids to summarize'],
        'prioritize_objects': ['objects: List of objects to prioritize'],
        'add_work_items_to_sprint': ['work_ids: List of objects to be added', 'sprint_id: Id of the sprint'],
        'get_sprint_id': [],
        'get_similar_work_items': ['work_id: id of work item to find similar items to'],
        'search_object_by_name': ['query: String to search for'],
        'create_actionable_tasks_from_text': ['text: Text to create actionable tasks from'],
        'who_am_i': []
    }

    For the receiving the given output on the given query, what should be my optimized prompt.
   """

  user_prompt = f""": Given Input: {query}  Given Output:{tools, arguments} """

  final_prompt = system_prompt + "\n" + user_prompt
  messages=[{
      "role":"user",
      "content":final_prompt
  }]

  responses=openai.ChatCompletion.create(
      model=model,
      messages=messages,
      temperature=0
  )

  return responses.choices[0].message['content']

# %%
optimized_prompts=[]
for i in range(len(queries)):
  prompt=get_optimized_prompt(queries[i], tool_results[i],argument_predictions[i])
  optimized_prompts.append(prompt)

# %%
optimized_prompts
# Out:
# ['To receive the given output on the given query, you can use the following optimized prompt:\n\nPrompt: Use the \'get_similar_work_items\' tool to find work items similar to \'don:core:dvrv-us-1:devo/0:issue/1\'. Then, use the \'summarize_objects\' tool to summarize the list of objects returned by the previous tool.\n\nCode:\n```python\ntools_arguments = {\n    \'get_similar_work_items\': [\'work_id: id of work item to find similar items to\'],\n    \'summarize_objects\': [\'objects: List of object ids to summarize\']\n}\n\ntools_input = {\n    \'get_similar_work_items\': {\n        \'work_id\': \'don:core:dvrv-us-1:devo/0:issue/1\'\n    },\n    \'summarize_objects\': {\n        \'objects\': \'$$PREV[0]\'\n    }\n}\n\noutput = (\'get_similar_work_items\', \'summarize_objects\')\n\nprompt = f"Given Input: Summarize work items similar to \'don:core:dvrv-us-1:devo/0:issue/1\'\\nGiven Output: {output}\\n\\n"\n\nfor tool in output:\n    prompt += f"{tool}:\\n"\n    for argument in tools_arguments[tool]:\n        prompt += f"- {argument}\\n"\n    prompt += f"{tool}:\\n"\n    for argument in tools_arguments[tool]:\n        prompt += f"    {argument}\\n"\n    prompt += "\\n"\n\nprint(prompt)\n```\n\nThis prompt will generate the following output:\n\n```\nGiven Input: Summarize work items similar to \'don:core:dvrv-us-1:devo/0:issue/1\'\nGiven Output: (\'get_similar_work_items\', \'summarize_objects\')\n\nget_similar_work_items:\n- work_id: id of work item to find similar items to\nget_similar_work_items:\n    work_id: id of work item to find similar items to\n\nsummarize_objects:\n- objects: List of object ids to summarize\nsummarize_objects:\n    objects: $$PREV[0]\n```\n\nYou can use this prompt to receive the desired output.',
#  'To retrieve and summarize the status updates for all user stories assigned to the team member Jane Doe in the last sprint, you can use the following prompt:\n\nPrompt: Use the \'search_object_by_name\' tool to find the user ID for the team member Jane Doe. Then, use the \'get_sprint_id\' tool to retrieve the ID of the last sprint. Next, use the \'works_list\' tool to filter the work items owned by the user ID obtained from the previous step and with the type \'user story\'. Finally, use the \'summarize_objects\' tool to summarize the status updates for the retrieved work items.\n\nInput: \nRetrieve and summarize the status updates for all user stories assigned to the team member Jane Doe in the last sprint.\n\nOutput:\n{\n  "search_object_by_name": {\n    "argument_name": "query",\n    "argument_value": "Jane Doe"\n  },\n  "get_sprint_id": {},\n  "works_list": {\n    "argument_name": ["owned_by", "type"],\n    "argument_value": ["$$PREV[0]", ["user story"]]\n  },\n  "summarize_objects": {\n    "argument_name": "objects",\n    "argument_value": "$$PREV[2]"\n  }\n}',
#  'To optimize the prompt, you can provide the following:\n\n"Please provide a list of tasks completed during the current sprint of project devtest. The available tools that can help with this are \'get_sprint_id\', \'works_list\', and \'summarize_objects\'. \n\nFor \'get_sprint_id\', no arguments are needed as it simply returns the id of the current sprint.\n\nFor \'works_list\', you can use the following arguments:\n- \'type\': Set it to \'task\' to filter for tasks completed during the current sprint.\n- \'stage.name\': Set it to \'completed\' to filter for completed tasks.\n\nFor \'summarize_objects\', you can use the output of the \'works_list\' tool as the \'objects\' argument.\n\nThe JSON format for the query would look like this:\n\n{\n  "get_sprint_id": [],\n  "works_list": [\n    {\n      "argument_name": "type",\n      "argument_value": "task"\n    },\n    {\n      "argument_name": "stage.name",\n      "argument_value": "completed"\n    }\n  ],\n  "summarize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": "output_of_works_list_tool"\n    }\n  ]\n}\n\nPlease provide the necessary values for the arguments and execute the query."',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the input to summarize the issues tagged with \'Security\' in the current sprint and recommend actions to resolve them, provide the sequence of tools and their corresponding arguments to achieve this."\n\nThis prompt clearly specifies the desired output and asks for the sequence of tools and their arguments to achieve it.',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the input to summarize all tasks listed with \'UI/UX\' in the current sprint, provide the sequence of tools and their corresponding arguments to achieve this. The available tools are \'get_sprint_id\', \'works_list\', and \'summarize_objects\'. The arguments for each tool are as follows:\n\n- \'get_sprint_id\': No arguments required.\n- \'works_list\': \n  - \'type\': [\'task\']\n  - \'applies_to_part\': [\'UI/UX\']\n- \'summarize_objects\':\n  - \'objects\': [\'$$PREV[1]\']\n\nPlease provide the optimized prompt to achieve the desired output."',
#  'To receive the given output on the given query, you can use the following optimized prompt:\n\nPrompt: Use the tools \'get_similar_work_items\', \'summarize_objects\', and \'prioritize_objects\' to get work items similar to "DEV", summarize them, and prioritize them.\n\nCode:\n```python\ntools_arguments = {\n    \'get_similar_work_items\': [\'work_id: "DEV"\'],\n    \'summarize_objects\': [\'objects: $$PREV[0]\'],\n    \'prioritize_objects\': [\'objects: $$PREV[1]\']\n}\n\noutput = {\n    \'get_similar_work_items\': {\n        \'work_id\': \'DEV\'\n    },\n    \'summarize_objects\': {\n        \'objects\': \'$$PREV[0]\'\n    },\n    \'prioritize_objects\': {\n        \'objects\': \'$$PREV[1]\'\n    }\n}\n\nprompt = "Given Input: Get work items similar to \'DEV\', summarize and prioritize them\\nGiven Output: (\'get_similar_work_items\', \'summarize_objects\', \'prioritize_objects\')\\n\\n" + str(tools_arguments) + "\\n\\n" + str(output)\n```\n\nThis prompt defines the tools and their arguments required to achieve the desired output. It also includes the given input and output for clarity.',
#  'To prioritize tasks associated with "Internal" in the current sprint backlog, you can use the following sequence of tools and their arguments:\n\n1. Use the tool "get_sprint_id" without any arguments to retrieve the id of the current sprint.\n\n2. Use the tool "works_list" with the argument "applies_to_part" set to ["Internal"] to filter the work items relevant to "Internal".\n\n3. Use the tool "prioritize_objects" with the argument "objects" set to ["$$PREV[1]"] to prioritize the work items obtained from the previous step.\n\nHere is the optimized prompt you can use:\n\nPrompt: Prioritize tasks associated with "Internal" in the current sprint backlog.\nTools: [\'get_sprint_id\', \'works_list\', \'prioritize_objects\']\nArguments:\n- get_sprint_id: []\n- works_list: [{\'argument_name\': \'applies_to_part\', \'argument_value\': [\'Internal\']}]\n- prioritize_objects: [{\'argument_name\': \'objects\', \'argument_value\': [\'$$PREV[1]\']}]\n\nPlease note that the "$$PREV[1]" placeholder refers to the output of the previous tool, which in this case is the list of work items obtained from the "works_list" tool.',
#  'To optimize the prompt, you can use the following:\n\n"Given the customer transcript \'text\', perform the following actions: create actionable tasks from the text, add the created work items to the current sprint, retrieve the id of the current sprint, summarize the objects, and prioritize the objects. \n\nThe values for the arguments for each tool are as follows:\n\n- create_actionable_tasks_from_text:\n  - text: \'Given a customer transcript "text", create work items, add them to the current sprint, summarize and prioritize them\'\n\n- add_work_items_to_sprint:\n  - work_ids: $$PREV[0]\n  - sprint_id: $$PREV[2]\n\n- get_sprint_id: No arguments required\n\n- summarize_objects:\n  - objects: $$PREV[1]\n\n- prioritize_objects:\n  - objects: $$PREV[3]"\n\nThe expected output will be:\n("[\'create_actionable_tasks_from_text\', \'add_work_items_to_sprint\', \'get_sprint_id\', \'summarize_objects\', \'prioritize_objects\']", \'The values for the arguments for the given tools from the text are as follows:\\n\\n{\\n  "create_actionable_tasks_from_text": [\\n    {\\n      "argument_name": "text",\\n      "argument_value": "Given a customer transcript \\\\"text\\\\", create work items, add them to the current sprint, summarize and prioritize them"\\n    }\\n  ],\\n  "add_work_items_to_sprint": [\\n    {\\n      "argument_name": "work_ids",\\n      "argument_value": "$$PREV[0]"\\n    },\\n    {\\n      "argument_name": "sprint_id",\\n      "argument_value": "$$PREV[2]"\\n    }\\n  ],\\n  "get_sprint_id": [],\\n  "summarize_objects": [\\n    {\\n      "argument_name": "objects",\\n      "argument_value": "$$PREV[1]"\\n    }\\n  ],\\n  "prioritize_objects": [\\n    {\\n      "argument_name": "objects",\\n      "argument_value": "$$PREV[3]"\\n    }\\n  ]\\n}\')',
#  'To receive the given output on the given query, you can use the following prompt:\n\nInput: Find work items similar to "user/ref:issue" and summarize them.\n\nOutput: ("[\'get_similar_work_items\', \'summarize_objects\']", \'{"get_similar_work_items": {"argument_name": "work_id", "argument_value": "user/ref:issue"}, "summarize_objects": {"argument_name": "objects", "argument_value": "$$PREV[0]"}}\')',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the input to summarize and prioritize issues of P0 for user Harry, provide the sequence of tools and their corresponding arguments to achieve the desired output."\n\nExample prompt:\n\nInput: Summarize and prioritize issues of P0 for user Harry\n\nOutput: \nTools: [\'works_list\', \'search_object_by_name\', \'summarize_objects\', \'prioritize_objects\']\nArguments:\n- works_list:\n  - applies_to_part: ["issue.priority"]\n  - issue.priority: ["P0"]\n  - owned_by: ["Harry"]\n- summarize_objects:\n  - objects: ["$$PREV[0]"]\n- prioritize_objects:\n  - objects: ["$$PREV[1]"]\n\nPlease provide the optimized prompt for the given output on the given query.',
#  "To optimize the prompt for the given input and output, you can use the following:\n\nPrompt: Use the available tools to find the task assigned to user Mark and add it to the current sprint.\n\nCode:\ntools_arguments = {\n    'works_list': ['applies_to_part', 'created_by', 'issue.priority', 'issue.rev_orgs', 'limit', 'owned_by', 'stage.name', 'ticket.needs_response', 'ticket.rev_org', 'ticket.severity', 'ticket.source_channel', 'type'],\n    'summarize_objects': ['objects'],\n    'prioritize_objects': ['objects'],\n    'add_work_items_to_sprint': ['work_ids', 'sprint_id'],\n    'get_sprint_id': [],\n    'get_similar_work_items': ['work_id'],\n    'search_object_by_name': ['query'],\n    'create_actionable_tasks_from_text': ['text'],\n    'who_am_i': []\n}\n\ntools_order = ['search_object_by_name', 'works_list', 'get_sprint_id', 'add_work_items_to_sprint']\n\narguments = {\n    'search_object_by_name': {\n        'query': 'Mark'\n    },\n    'works_list': {\n        'owned_by': ['$$PREV[0]'],\n        'type': ['task']\n    },\n    'get_sprint_id': {},\n    'add_work_items_to_sprint': {\n        'work_ids': ['$$PREV[1]'],\n        'sprint_id': '$$PREV[2]'\n    }\n}\n\noutput = (tools_order, arguments)\n\nprint(output)",
#  'Prompt: Use the \'works_list\' tool to filter tasks for the rev organization SigmaSquad with a high severity ticket. Then, use the \'prioritize_objects\' tool to prioritize the filtered tasks.\n\nInput: Prioritize all the tasks for the rev organization SigmaSquad which have a high severity ticket\n\nOutput: \n```\n{\n  "works_list": [\n    {\n      "argument_name": "type",\n      "argument_value": ["task"]\n    },\n    {\n      "argument_name": "ticket.rev_org",\n      "argument_value": ["SigmaSquad"]\n    },\n    {\n      "argument_name": "ticket.severity",\n      "argument_value": ["high"]\n    }\n  ],\n  "prioritize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": ["$$PREV[0]"]\n    }\n  ]\n}\n```',
#  'Optimized Prompt: \n\nTo get work items that you have created and summarize them, you can use the following tools: \'works_list\', \'who_am_i\', and \'summarize_objects\'. \n\nTo achieve this, you can provide the following arguments to the tools:\n\n- For the \'works_list\' tool, you can use the \'created_by\' argument and set its value to "$$PREV[1]".\n- For the \'summarize_objects\' tool, you can use the \'objects\' argument and set its value to "$$PREV[0]".\n\nBy using these tools and arguments, you will be able to retrieve the work items you have created and summarize them.',
#  'Prompt: Use the \'works_list\' tool to filter issues under the triage stage for the rev organizations Ajin and Kalidas, and with the P0 priority. Then, use the \'summarize_objects\' tool to summarize the resulting list of issues. Finally, use the \'prioritize_objects\' tool to prioritize the summarized objects.\n\nInput: Summarize and prioritize the issues under the triage stage for the rev organization Ajin and the P0 priority issues for the rev organization Kalidas\n\nOutput: \n{\n  "works_list": [\n    {\n      "argument_name": "stage.name",\n      "argument_value": ["triage"]\n    },\n    {\n      "argument_name": "issue.rev_orgs",\n      "argument_value": ["Ajin", "Kalidas"]\n    },\n    {\n      "argument_name": "issue.priority",\n      "argument_value": ["P0"]\n    }\n  ],\n  "summarize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": ["$$PREV[0]"]\n    }\n  ],\n  "prioritize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": ["$$PREV[1]"]\n    }\n  ]\n}',
#  'Prompt: Use the available tools to achieve the following tasks:\n\n1. Create actionable tasks from the text "T detailing the recent team meeting".\n2. Get a list of tickets coming in from Discord from a customer named Raja.\n3. Add the common tasks to the current sprint.\n\nPlease provide the optimized prompt to receive the desired output.',
#  'Prompt: Use the following tools to summarize and prioritize tasks labeled "Backend" from the last two sprints in the project codehub and provide recommendations to resolve them:\n\n1. Use the \'works_list\' tool to filter work items that apply to the "Backend" part, are of type "task", are in the stages of the last two sprints, and are associated with the organization "codehub".\n\n2. Use the \'summarize_objects\' tool to summarize the list of work items obtained from the previous step.\n\n3. Use the \'prioritize_objects\' tool to prioritize the summarized work items.\n\n4. Use the \'get_sprint_id\' tool to retrieve the id of the current sprint.\n\nPlease provide the necessary arguments for each tool as follows:\n\n- For the \'works_list\' tool:\n  - Set \'applies_to_part\' to ["Backend"]\n  - Set \'type\' to ["task"]\n  - Set \'stage.name\' to ["last two sprints"]\n  - Set \'issue.rev_orgs\' to ["codehub"]\n\n- For the \'summarize_objects\' tool:\n  - Set \'objects\' to ["$$PREV[0]"] (where $$PREV[0] refers to the output of the previous tool)\n\n- For the \'prioritize_objects\' tool:\n  - Set \'objects\' to ["$$PREV[1]"] (where $$PREV[1] refers to the output of the previous tool)\n\n- For the \'get_sprint_id\' tool, no arguments are required.\n\nPlease provide the optimized prompt based on the given input and output.',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the output: (\'["create_actionable_tasks_from_text", "search_object_by_name", "get_similar_work_items", "summarize_objects"]\', \'{\\n  "create_actionable_tasks_from_text": {\\n    "text": "Delve into the cosmic ponderings: Explore and compare diverse cultural and scientific perspectives on the question, \\\\"What is the nature of existence?\\\\""\\n  },\\n  "search_object_by_name": {\\n    "query": "What is the nature of existence?"\\n  },\\n  "get_similar_work_items": {\\n    "work_id": "$$PREV[1]"\\n  },\\n  "summarize_objects": {\\n    "objects": "$$PREV[2]"\\n  }\\n}\'), provide an optimized prompt to generate this output."\n\nThis prompt clearly states the given output and asks for an optimized prompt to generate the same output.',
#  'To retrieve and distill all work items similar to "BUG-456," synthesize them into coherent issues, and prioritize them for immediate resolution, you can use the following prompt:\n\n```\n[\n  \'get_similar_work_items\': {\n    \'work_id\': \'BUG-456\'\n  },\n  \'summarize_objects\': {\n    \'objects\': \'$$PREV[0]\'\n  },\n  \'prioritize_objects\': {\n    \'objects\': \'$$PREV[1]\'\n  }\n]\n```\n\nThis prompt uses the tools \'get_similar_work_items\', \'summarize_objects\', and \'prioritize_objects\' to achieve the desired outcome. The \'get_similar_work_items\' tool is used to find work items similar to "BUG-456", the \'summarize_objects\' tool is used to summarize the retrieved work items, and the \'prioritize_objects\' tool is used to sort the summarized work items by priority.',
#  'Optimized Prompt: \n\nYou can use the "works_list" tool to retrieve a list of work-items matching the request. To filter the works relevant to the REV(customer) N V organization, you can provide the "issue.rev_orgs" argument with the value ["REV(customer) N V"].\n\nAfter obtaining the list of work-items, you can use the "summarize_objects" tool to summarize the objects. To do this, provide the "objects" argument with the value ["$$PREV[0]"], which refers to the first item in the previous output.\n\nHere is an example of how you can use these tools:\n\n```\nworks_list(applies_to_part: [], created_by: [], issue.priority: [], issue.rev_orgs: ["REV(customer) N V"], limit: 0, owned_by: [], stage.name: [], ticket.needs_response: false, ticket.rev_org: [], ticket.severity: [], ticket.source_channel: [], type: [])\nsummarize_objects(objects: ["$$PREV[0]"])\n```\n\nThis will return the list of work-items matching the REV(customer) N V organization and summarize the objects.',
#  'To generate the given output on the given query, you can use the following prompt:\n\n"Use the \'create_actionable_tasks_from_text\' tool to extract actionable tasks from the minutes of the latest team meeting. Then, use the \'get_sprint_id\' tool to retrieve the id of the current sprint. Finally, use the \'add_work_items_to_sprint\' tool to add the extracted tasks to the current sprint. The arguments for the \'create_actionable_tasks_from_text\' tool should be {\'text\': \'Analyze the minutes from the latest team meeting, generate a task list\'}. The \'add_work_items_to_sprint\' tool should take the following arguments: {\'work_ids\': $$PREV[0], \'sprint_id\': $$PREV[1]}."',
#  'Prompt: Use the \'works_list\' tool to extract work tasks with the keyword "Analytics". Then, use the \'summarize_objects\' tool to summarize the extracted tasks. Finally, use the \'prioritize_objects\' tool to arrange the summarized tasks by priority.\n\nOptimized Prompt: Extract work tasks with the keyword "Analytics" using the \'works_list\' tool. Summarize the extracted tasks using the \'summarize_objects\' tool. Arrange the summarized tasks by priority using the \'prioritize_objects\' tool.',
#  'To receive the given output on the given query, you can use the following prompt:\n\nPrompt: "Given the input \'Reflect on the concept of time\', use the appropriate tool to obtain the desired output."\n\nOptimized Prompt: "Use the \'create_actionable_tasks_from_text\' tool with the argument \'text\' set to \'Reflect on the concept of time\' to obtain the desired output."',
#  'Prompt: Compile a detailed list of high-impact tickets originating from Microsoft Teams from customer Rahul and generate a concise overview.\n\nOptimized Prompt: Use the \'search_object_by_name\' tool to search for the customer named "Rahul". Then, use the \'works_list\' tool to filter the works created by the customer, with the source channel set to "Microsoft Teams", severity set to "high-impact", and type set to "ticket". Next, use the \'prioritize_objects\' tool to prioritize the list of tickets obtained from the previous step. Finally, use the \'summarize_objects\' tool to generate a concise overview of the prioritized tickets.',
#  'To receive the given output on the given query, you can use the following prompt:\n\n"Use the \'create_actionable_tasks_from_text\' tool to create actionable tasks from the given text \'Contemplate the meaning of knowledge\'."',
#  'Prompt: Use the \'works_list\' tool to filter high-severity tickets created by me. Then, use the \'prioritize_objects\' tool to prioritize the filtered tickets. Finally, use the \'summarize_objects\' tool to generate a comprehensive summary of the prioritized tickets.\n\nOptimized Prompt: \n\nTool: works_list\nArguments:\n- created_by: [$$PREV[0]]\n- ticket.severity: ["high"]\n- type: ["ticket"]\n\nTool: prioritize_objects\nArguments:\n- objects: [$$PREV[1]]\n\nTool: summarize_objects\nArguments:\n- objects: [$$PREV[2]]',
#  'Prompt: Use the available tools to retrieve a list of urgent emails and summarize them.\n\nUser Input: Give a list of urgent emails to read and summarize these emails\n\nExpected Output: \n- Tool 1: works_list\n  - Arguments:\n    - issue.priority: ["urgent"]\n    - type: ["email"]\n- Tool 2: prioritize_objects\n- Tool 3: summarize_objects\n  - Arguments:\n    - objects: ["$$PREV[0]"]\n\nOptimized Prompt: Use the \'works_list\' tool to retrieve a list of urgent emails with the specified arguments. Then, use the \'prioritize_objects\' tool to prioritize the retrieved emails. Finally, use the \'summarize_objects\' tool to summarize the prioritized emails.',
#  'To receive the given output on the given query, you can use the following prompt:\n\n"Find the tool and its arguments that can be used to create actionable tasks from the given text: \'send an email to admin about the problems encountered during completion of tasks\'."',
#  'Prompt: Use the available tools to search for bug reports similar to "Null Pointer Exception in Module" among the critical bug reports and prioritize the resulting work items.\n\nOptimized Prompt: Use the \'search_object_by_name\' tool to search for bug reports with the query "Null Pointer Exception in Module". Then, use the \'get_similar_work_items\' tool to find work items similar to the identified bug reports. Finally, use the \'prioritize_objects\' tool to prioritize the resulting work items.',
#  'To optimize the prompt for the given input and output, you can use the following:\n\nPrompt: Use the available tools to search for a work item named "Backend Refactoring", summarize it, and add it to the current sprint.\n\nGiven Output: \n("[\'search_object_by_name\', \'summarize_objects\', \'get_sprint_id\', \'add_work_items_to_sprint\']", \n\'{\\n  "search_object_by_name": {\\n    "argument_name": "query",\\n    "argument_value": "Backend Refactoring"\\n  },\\n  "summarize_objects": {\\n    "argument_name": "objects",\\n    "argument_value": "$$PREV[0]"\\n  },\\n  "get_sprint_id": {},\\n  "add_work_items_to_sprint": {\\n    "work_ids": {\\n      "argument_name": "work_ids",\\n      "argument_value": "$$PREV[1]"\\n    },\\n    "sprint_id": {\\n      "argument_name": "sprint_id",\\n      "argument_value": "$$PREV[2]"\\n    }\\n  }\\n}\')\n\nOptimized Prompt: Use the "search_object_by_name" tool to find the work item named "Backend Refactoring". Then, use the "summarize_objects" tool to summarize the found work item. Next, use the "get_sprint_id" tool to get the id of the current sprint. Finally, use the "add_work_items_to_sprint" tool to add the summarized work item to the current sprint.\n\nThis prompt provides clear instructions on which tools to use and in what order to achieve the desired outcome.',
#  'Prompt: Use the available tools to extract tasks from the given text, prioritize them, and add them to the current sprint.\n\nGiven Input: Extract tasks from the text “Implement the payment gateway and test the checkout flow”, prioritize them, and add them to the current sprint.\n\nGiven Output: ("[\'create_actionable_tasks_from_text\', \'prioritize_objects\', \'get_sprint_id\', \'add_work_items_to_sprint\']", \'{\\n  "create_actionable_tasks_from_text": {\\n    "argument_name": "text",\\n    "argument_value": "Implement the payment gateway and test the checkout flow"\\n  },\\n  "prioritize_objects": {\\n    "argument_name": "objects",\\n    "argument_value": "$$PREV[0]"\\n  },\\n  "get_sprint_id": {},\\n  "add_work_items_to_sprint": {\\n    "work_ids": {\\n      "argument_name": "work_ids",\\n      "argument_value": "$$PREV[1]"\\n    },\\n    "sprint_id": {\\n      "argument_name": "sprint_id",\\n      "argument_value": "$$PREV[2]"\\n    }\\n  }\\n}\')\n\nOptimized Prompt: Use the "create_actionable_tasks_from_text" tool to extract tasks from the given text "Implement the payment gateway and test the checkout flow". Then, use the "prioritize_objects" tool to prioritize the extracted tasks. Next, use the "get_sprint_id" tool to get the id of the current sprint. Finally, use the "add_work_items_to_sprint" tool to add the prioritized tasks to the current sprint.',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\nPrompt: Use the \'works_list\' tool along with the \'search_object_by_name\' tool to find work items related to "API Development".\n\nGiven Output: ("[\'works_list\', \'search_object_by_name\']", \'{\\n  "search_object_by_name": [\\n    {\\n      "argument_name": "query",\\n      "argument_value": "API Development"\\n    }\\n  ]\\n}\')',
#  "To summarize the current user's tasks, you can use the 'who_am_i' tool to get the id of the current user. Then, you can use the 'works_list' tool to retrieve a list of work-items matching the request. Finally, you can use the 'summarize_objects' tool to summarize the list of objects obtained from the 'works_list' tool.",
#  'Prompt: Please provide a query related to the available tools and their arguments.',
#  "Prompt: Use the 'works_list' tool to retrieve a list of tickets that meet the following criteria: \n- Type: ticket\n- Source channel: email\n- Needs response: true\n- Limit: 30\n- Rev org: Gemini\n\nAdditionally, use the 'who_am_i' tool to retrieve the current user's ID.\n\nFinally, prioritize the retrieved tickets using the 'prioritize_objects' tool.\n\nTool Arguments:\n- works_list:\n  - type: ['ticket']\n  - ticket.source_channel: ['email']\n  - ticket.needs_response: true\n  - limit: 30\n  - ticket.rev_org: ['Gemini']\n- who_am_i: []\n- prioritize_objects: []",
#  'Prompt: Use the available tools to get all the tasks that are a part of INS69, summarize them, and create specific tasks from that summary.\n\nGiven Output:("[\'search_object_by_name\', \'works_list\', \'summarize_objects\', \'create_actionable_tasks_from_text\']", \'{\\n  "search_object_by_name": [\\n    {\\n      "argument_name": "query",\\n      "argument_value": "INS69"\\n    }\\n  ],\\n  "works_list": [\\n    {\\n      "argument_name": "applies_to_part",\\n      "argument_value": ["$$PREV[0]"]\\n    }\\n  ],\\n  "summarize_objects": [\\n    {\\n      "argument_name": "objects",\\n      "argument_value": ["$$PREV[1]"]\\n    }\\n  ],\\n  "create_actionable_tasks_from_text": [\\n    {\\n      "argument_name": "text",\\n      "argument_value": ["$$PREV[2]"]\\n    }\\n  ]\\n}\')\n\nOptimized Prompt: Use the \'search_object_by_name\' tool to find the object with the query "INS69". Then, use the \'works_list\' tool with the argument \'applies_to_part\' set to the result of the previous tool. Next, use the \'summarize_objects\' tool with the argument \'objects\' set to the result of the previous tool. Finally, use the \'create_actionable_tasks_from_text\' tool with the argument \'text\' set to the result of the previous tool.',
#  'Prompt: Use the available tools to search for works related to "Navishkar", prioritize them, and add them to the current sprint.\n\nGiven Output: \n("[\'search_object_by_name\', \'works_list\', \'prioritize_objects\', \'get_sprint_id\', \'add_work_items_to_sprint\']", \'{\\n  "search_object_by_name": {\\n    "argument_name": "query",\\n    "argument_value": "Navishkar"\\n  },\\n  "works_list": {\\n    "argument_name": "applies_to_part",\\n    "argument_value": "$$PREV[0]"\\n  },\\n  "prioritize_objects": {\\n    "argument_name": "objects",\\n    "argument_value": "$$PREV[1]"\\n  },\\n  "get_sprint_id": {},\\n  "add_work_items_to_sprint": {\\n    "argument_name": ["work_ids", "sprint_id"],\\n    "argument_value": ["$$PREV[2]", "$$PREV[3]"]\\n  }\\n}\')\n\nOptimized Prompt: Use the "search_object_by_name" tool to search for works related to "Navishkar". Then, use the "works_list" tool to retrieve a list of work-items matching the search query. Next, use the "prioritize_objects" tool to prioritize the retrieved work-items. After that, use the "get_sprint_id" tool to get the id of the current sprint. Finally, use the "add_work_items_to_sprint" tool to add the prioritized work-items to the current sprint.',
#  "Prompt: Use the 'works_list' tool to filter for tickets with 'blocker' severity for the rev organization 'Llama' and 'P0' priority issues for the rev organization 'Falcon'. Then, use the 'summarize_objects' tool to summarize the list of objects obtained from the previous step. Finally, use the 'prioritize_objects' tool to prioritize the summarized objects.",
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Get all the tasks that bear a resemblance to \'Finetuning GPT-3.5-Turbo\', and debrief me."\n\nOptimized Prompt:\n"Use the \'get_similar_work_items\' tool to find work items similar to \'Finetuning GPT-3.5-Turbo\'. Then, use the \'summarize_objects\' tool to summarize the list of objects obtained from the previous tool. Provide the arguments for each tool as follows: \n\nFor \'get_similar_work_items\':\n- Set the argument \'work_id\' to \'Finetuning GPT-3.5-Turbo\'.\n\nFor \'summarize_objects\':\n- Set the argument \'objects\' to the value obtained from the previous tool ($$PREV[0])."\n\nThis optimized prompt provides clear instructions on which tools to use and how to set the arguments for each tool to achieve the desired output.',
#  'Prompt: Use the following tools and their arguments to find all tasks assigned to you that need to be added to a sprint and search for the task "URGENT" within them:\n\nTools to use: \'who_am_i\', \'works_list\', \'search_object_by_name\', \'add_work_items_to_sprint\'\n\nArguments for each tool:\n- \'who_am_i\': No arguments needed.\n- \'works_list\': \n  - \'type\': Set the value to [\'task\'] to filter for tasks.\n  - \'owned_by\': Set the value to [\'$$PREV[0]\'] to filter for tasks assigned to you.\n- \'search_object_by_name\':\n  - \'query\': Set the value to "URGENT" to search for the task with the name "URGENT".\n- \'add_work_items_to_sprint\':\n  - \'work_ids\': Set the value to [\'$$PREV[2]\'] to add the found task to a sprint.\n\nOutput:\n{\n  "who_am_i": [],\n  "works_list": [\n    {\n      "argument_name": "type",\n      "argument_value": ["task"]\n    },\n    {\n      "argument_name": "owned_by",\n      "argument_value": ["$$PREV[0]"]\n    }\n  ],\n  "search_object_by_name": [\n    {\n      "argument_name": "query",\n      "argument_value": "URGENT"\n    }\n  ],\n  "add_work_items_to_sprint": [\n    {\n      "argument_name": "work_ids",\n      "argument_value": ["$$PREV[2]"]\n    }\n  ]\n}',
#  'To receive the given output on the given query, you can use the following prompt:\n\n"Use the \'create_actionable_tasks_from_text\' tool to extract actionable tasks from the given text: \'Send an email to the IT department detailing recent technical challenges faced during project completion and request assistance.\'"',
#  'To retrieve a list of your replies in response to the email related to the finance meeting, you can use the following tools:\n\n1. `search_object_by_name`: Use this tool with the argument `query` set to the relevant search term to find the object ID of the email related to the finance meeting.\n\n2. `works_list`: Once you have the object ID of the email, use this tool with the argument `applies_to_part` set to the object ID to filter and retrieve a list of your replies.\n\nHere is an example prompt you can use to get the desired output:\n\n```\nTool: search_object_by_name\nArgument: query = "finance meeting email"\n\nTool: works_list\nArgument: applies_to_part = [object_id_of_finance_meeting_email]\n```\n\nPlease note that the given text does not provide enough information to extract values for the arguments of the mentioned tools \'search_object_by_name\' and \'works_list\'.',
#  'To receive the given output on the given query, you can use the following optimized prompt:\n\nPrompt: Use the available tools to organize and prioritize P1 issues, then seamlessly integrate them into the ongoing sprint.\n\nTools:\n1. Use the \'works_list\' tool to filter works relevant to the specified criteria:\n   - Apply the filter \'issue.priority\' with the value ["P1"].\n\n2. Use the \'prioritize_objects\' tool to prioritize the filtered works:\n   - Provide the list of objects obtained from the previous step as the input.\n\n3. Use the \'get_sprint_id\' tool to retrieve the id of the current sprint.\n\n4. Use the \'add_work_items_to_sprint\' tool to add the prioritized work items to the ongoing sprint:\n   - Provide the list of work item ids obtained from the previous step as the \'work_ids\' input.\n   - Provide the id of the current sprint as the \'sprint_id\' input.\n\nOutput:\n{\n  "works_list": {\n    "issue.priority": ["P1"]\n  },\n  "prioritize_objects": {\n    "objects": ["$$PREV[0]"]\n  },\n  "get_sprint_id": {},\n  "add_work_items_to_sprint": {\n    "work_ids": ["$$PREV[1]"],\n    "sprint_id": ["$$PREV[2]"]\n  }\n}',
#  'To optimize the prompt for the given input and output, you can use the following:\n\nPrompt: Use the available tools to summarize the tasks coming from the Microsoft Team and Zoom. Then, add the summarized tasks to a sprint.\n\nGiven Output:\n("[\'search_object_by_name\', \'works_list\', \'summarize_objects\', \'get_sprint_id\', \'add_work_items_to_sprint\']", \'{\\n  "search_object_by_name": [],\\n  "works_list": [\\n    {\\n      "argument_name": "ticket.source_channel",\\n      "argument_value": ["Microsoft Team", "Zoom"]\\n    },\\n    {\\n      "argument_name": "type",\\n      "argument_value": ["task"]\\n    }\\n  ],\\n  "summarize_objects": [\\n    {\\n      "argument_name": "objects",\\n      "argument_value": "$$PREV[1]"\\n    }\\n  ],\\n  "get_sprint_id": [],\\n  "add_work_items_to_sprint": [\\n    {\\n      "argument_name": "work_ids",\\n      "argument_value": "$$PREV[2]"\\n    },\\n    {\\n      "argument_name": "sprint_id",\\n      "argument_value": "$$PREV[3]"\\n    }\\n  ]\\n}\')\n\nOptimized Prompt: Use the \'search_object_by_name\' tool to find the tasks from the Microsoft Team and Zoom. Then, use the \'works_list\' tool to retrieve the tasks matching the found objects. Next, use the \'summarize_objects\' tool to summarize the retrieved tasks. After that, use the \'get_sprint_id\' tool to get the id of the current sprint. Finally, use the \'add_work_items_to_sprint\' tool to add the summarized tasks to the sprint.\n\nGiven Input: Summarise the task coming from the Microsoft Team and coming from the Zoom and add them to sprint.\n\nGiven Output:\n("[\'search_object_by_name\', \'works_list\', \'summarize_objects\', \'get_sprint_id\', \'add_work_items_to_sprint\']", \'{\\n  "search_object_by_name": [],\\n  "works_list": [\\n    {\\n      "argument_name": "ticket.source_channel",\\n      "argument_value": ["Microsoft Team", "Zoom"]\\n    },\\n    {\\n      "argument_name": "type",\\n      "argument_value": ["task"]\\n    }\\n  ],\\n  "summarize_objects": [\\n    {\\n      "argument_name": "objects",\\n      "argument_value": "$$PREV[1]"\\n    }\\n  ],\\n  "get_sprint_id": [],\\n  "add_work_items_to_sprint": [\\n    {\\n      "argument_name": "work_ids",\\n      "argument_value": "$$PREV[2]"\\n    },\\n    {\\n      "argument_name": "sprint_id",\\n      "argument_value": "$$PREV[3]"\\n    }\\n  ]\\n}\')',
#  'To receive the given output on the given query, you can use the following prompt:\n\nPrompt: "Please provide comments on the ICC World Cup final between India and Australia. Use the available tools and their arguments to generate the desired output.',
#  'To extract the required information, you can use the "search_object_by_name" tool with the argument "query" set to "chief minister of Andhra Pradesh state". This will return the ID of the matching object, which in this case would be the new chief minister of Andhra Pradesh state.',
#  'Prompt: Use the following tools and their arguments to provide an overview and prioritize critical issues for the organization "Pinnacle" and high-priority tasks for the organization "Skyward":\n\nTools:\n- `search_object_by_name`: Use the argument `query` with the values "Pinnacle" and "Skyward" to search for the organizations.\n- `works_list`: Use the arguments `issue.rev_orgs` with the values ["$$PREV[0]", "$$PREV[1]"], `issue.priority` with the values ["critical", "high"], and `type` with the values ["issue", "task"] to filter and retrieve the relevant work items.\n- `prioritize_objects`: Use the argument `objects` with the value "$$PREV[2]" to prioritize the retrieved work items.\n- `summarize_objects`: Use the argument `objects` with the value "$$PREV[3]" to summarize the prioritized work items.\n\nOutput:\n{\n  "search_object_by_name": [\n    {\n      "argument_name": "query",\n      "argument_value": "Pinnacle"\n    },\n    {\n      "argument_name": "query",\n      "argument_value": "Skyward"\n    }\n  ],\n  "works_list": [\n    {\n      "argument_name": "issue.rev_orgs",\n      "argument_value": ["$$PREV[0]", "$$PREV[1]"]\n    },\n    {\n      "argument_name": "issue.priority",\n      "argument_value": ["critical", "high"]\n    },\n    {\n      "argument_name": "type",\n      "argument_value": ["issue", "task"]\n    }\n  ],\n  "prioritize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": "$$PREV[2]"\n    }\n  ],\n  "summarize_objects": [\n    {\n      "argument_name": "objects",\n      "argument_value": "$$PREV[3]"\n    }\n  ]\n}',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the work item \'User Story:123\', retrieve and prioritize similar work items. Finally, summarize the status of these work items."\n\nThis prompt can be used to generate the desired output:\n\n{\n  "works_list": {\n    "issue.similar_to": "User Story:123"\n  },\n  "prioritize_objects": {\n    "objects": "$$PREV[0]"\n  },\n  "summarize_objects": {\n    "objects": "$$PREV[1]"\n  }\n}',
#  'To optimize the prompt for receiving the given output on the given query, you can use the following prompt:\n\n"Given the problem statement \'Inter IIT Tech Meet 12.0\', summarize all the problem statements and add them to a sprint. Use the available tools and their arguments to achieve this. The available tools are \'works_list\', \'summarize_objects\', \'get_sprint_id\', and \'add_work_items_to_sprint\'. The arguments for each tool are as follows: \n\n- \'works_list\': [\'applies_to_part\', \'created_by\', \'issue.priority\', \'issue.rev_orgs\', \'limit\', \'owned_by\', \'stage.name\', \'ticket.needs_response\', \'ticket.rev_org\', \'ticket.severity\', \'ticket.source_channel\', \'type\']\n- \'summarize_objects\': [\'objects\']\n- \'get_sprint_id\': []\n- \'add_work_items_to_sprint\': [\'work_ids\', \'sprint_id\']\n\nTo achieve the desired output, you can use the following sequence of tools and their arguments:\n\n1. Use the \'search_object_by_name\' tool with the argument \'query\' set to \'Inter IIT Tech Meet 12.0\' to find the relevant object.\n2. Use the \'works_list\' tool with the argument \'applies_to_part\' set to the value of the previous tool\'s output.\n3. Use the \'summarize_objects\' tool with the argument \'objects\' set to the value of the previous tool\'s output.\n4. Use the \'get_sprint_id\' tool to get the id of the current sprint.\n5. Use the \'add_work_items_to_sprint\' tool with the arguments \'work_ids\' set to the value of the previous tool\'s output and \'sprint_id\' set to the id of the current sprint.\n\nThe optimized prompt should be:\n\n\'{"tools": ["search_object_by_name", "works_list", "summarize_objects", "get_sprint_id", "add_work_items_to_sprint"], "arguments": {"search_object_by_name": {"query": "Inter IIT Tech Meet 12.0"}, "works_list": {"applies_to_part": ["$$PREV[0]"]}, "summarize_objects": {"objects": ["$$PREV[1]"]}, "get_sprint_id": {}, "add_work_items_to_sprint": {"work_ids": ["$$PREV[2]"], "sprint_id": "$$PREV[3]"}}}\'"']
